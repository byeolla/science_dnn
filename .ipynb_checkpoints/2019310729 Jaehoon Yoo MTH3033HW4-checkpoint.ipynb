# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import numpy as np
#       2 import matplotlib.pyplot as plt
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# # Lagrangian Interpolation

# %%
def lfun(xvals, jj, x):
    lval = np.ones(x.size)
    xjj = xvals[jj]
    xrem = xvals[:jj]
    xrem = np.append(xrem, xvals[jj+1:])
    denom = np.prod(xjj - xrem)
    for val in xrem:
        lval *= (x-val)
    return lval/denom
def lagran_interp(xvals, fvals, x):
    n = fvals.size
    ipoly = np.zeros(x.size)
    for jj in range(n):
        ipoly += fvals[jj]*lfun(xvals, jj, x)
    return ipoly

# %%
f1 = lambda x: x**2./(1.+x**4.)
xquery = np.linspace(-1., 1., int(1e3)+1)
ftrue = f1(xquery)
xnodes = xquery[::100]
fnodes = ftrue[::100]
# Out:
# 11

# %% [markdown]
# # Plotting

# %%
def interp_plotter(xnodes, fnodes, xquery, ftrue, c, o):
    finterp = lagran_interp(xnodes, fnodes, xquery)
    plt.plot(xquery, np.ma.log10(np.abs(ftrue - finterp)), label=f"nodes {xnodes.size}", c=c, alpha=o)
    plt.xlabel("$x$")
    plt.ylabel("$\log_{10}|Error|$")
    plt.grid(True)
    # plt.show()
    
def interp_plotter1(xnodes, fnodes, xquery, ftrue, c, label):
    finterp = lagran_interp(xnodes, fnodes, xquery)
    plt.plot(xquery, np.ma.log10(np.abs(ftrue - finterp)), label=label, c=c)
    plt.xlabel("$x$")
    plt.ylabel("$\log_{10}|Error|$")
    plt.grid(True)
    # plt.show()

# %%
for i, c in zip(range(1, 6), (f"C{k}" for k in range(0, 10))):
    xnodes = xquery[::100//i]
    fnodes = ftrue[::100//i]
    interp_plotter(xnodes, fnodes, xquery, ftrue, c, o=None)

plt.legend()
plt.show()

# %%
from numpy import interp


for i, c in zip(range(0, 5), (f"C{k}" for k in range(0, 10))):
    xnodes = np.linspace(-1, 1, 31+i)
    fnodes = f1(xnodes)

    interp_plotter(xnodes, fnodes, xquery, ftrue, c=None, o=None)
    plt.ylim(-20, -4)
    plt.legend(loc=4)
    # plt.title(f"Nodes {xnodes.size}")
plt.show() 

    
for i, c in zip(range(0, 5), (f"C{k}" for k in range(0, 10))):
    xnodes = np.linspace(-1, 1, 36+i)
    fnodes = f1(xnodes)

    interp_plotter(xnodes, fnodes, xquery, ftrue, c=None, o=None)
    plt.ylim(-20, -4)
    plt.legend(loc=4)
    # plt.title(f"Nodes {xnodes.size}")
plt.show() 

for i, c in zip(range(0, 10), (f"C{k}" for k in range(0, 10))):
    xnodes = np.linspace(-1, 1, 41+i)
    fnodes = f1(xnodes)
    cxnodes = np.linspace(-1, 1, 40+i)
    cfnodes = f1(cxnodes)
    interp_plotter(cxnodes, cfnodes, xquery, ftrue, c="r", o=0.2)
    interp_plotter(xnodes, fnodes, xquery, ftrue, c=None, o=0.5)
    plt.ylim(-20, -4)
    plt.legend(loc=4)
    plt.title(f"Nodes {xnodes.size}")
    plt.show()

# %% [markdown]
# Node 약 45개부터 양끝이 오차가 커지기 시작한다.

# %% [markdown]
# # Chevyshev

# %%
for i in range(1, 6):
    xnodes = xquery[::100//i]
    fnodes = ftrue[::100//i]
    interp_plotter1(xnodes, fnodes, xquery, ftrue, c=None, label='Equally sapced')

    ncheb = xnodes.size
    xcheb = np.cos(np.pi*(2.*np.arange(ncheb)+1.)/(2.*ncheb+2.))
    fcheb = f1(xcheb)
    finterp = lagran_interp(xcheb, fcheb, xquery)
    plt.plot(xquery, np.ma.log10(np.abs(ftrue-finterp)), ls='-', color='k', label='Chevyshev')
    plt.legend(loc=4)
    plt.title(f"Node {xnodes.size}")
    plt.show()

# %%
for i in range(0, 15):
    xnodes = np.linspace(-1, 1, 41+i)
    fnodes = f1(xnodes)

    interp_plotter1(xnodes, fnodes, xquery, ftrue, c=None, label='Equally Spaced')

    ncheb = xnodes.size
    xcheb = np.cos(np.pi*(2.*np.arange(ncheb)+1.)/(2.*ncheb+2.))
    fcheb = f1(xcheb)
    finterp = lagran_interp(xcheb, fcheb, xquery)
    plt.plot(xquery, np.ma.log10(np.abs(ftrue-finterp)), ls='-', color='k', label='Chevyshev')
    # plt.legend(loc=4)
    plt.title(f"Node {xnodes.size}")
    plt.ylim(-20, -4)
    plt.legend(loc=9)
    # plt.show() 
    plt.show()

# %% [markdown]
# Chebyshev points help resolve the Runge phenomena
