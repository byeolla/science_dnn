# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 1.12.1+cu113  Device: cuda

# %%
BATCH_SIZE = 32
EPOCHS = 20

# %%
train_dataset = datasets.MNIST(root = "../data/MNIST",
                               train = True,
                               download = True,
                               transform = transforms.ToTensor())

test_dataset = datasets.MNIST(root = "../data/MNIST",
                              train = False,
                              transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = BATCH_SIZE,
                                           shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ../data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ../data/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ../data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ../data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw

# %%
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 1, 28, 28]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(X_train[i, :, :, :].numpy().reshape(28, 28), cmap = "gray_r")
    plt.title('Class: ' + str(y_train[i].item()))

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)
        self.dropout_prob = 0.5
        self.batch_norm1 = nn.BatchNorm1d(512)
        self.batch_norm2 = nn.BatchNorm1d(256)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = self.fc1(x)
        x = self.batch_norm1(x)
        x = F.relu(x)
        x = F.dropout(x, training = self.training, p = self.dropout_prob)
        x = self.fc2(x)
        x = self.batch_norm2(x)
        x = F.relu(x)
        x = F.dropout(x, training = self.training, p = self.dropout_prob)
        x = self.fc3(x)
        x = F.log_softmax(x, dim = 1)
        return x

# %%
import torch.nn.init as init
def weight_init(m):
    if isinstance(m, nn.Linear):
        init.kaiming_uniform_(m.weight.data)

model = Net().to(DEVICE)
model.apply(weight_init)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum = 0.5)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
#   (batch_norm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image), 
                len(train_loader.dataset), 100. * batch_idx / len(train_loader), 
                loss.item()))

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
    
    test_loss /= (len(test_loader.dataset) / BATCH_SIZE)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Train Loss: 3.189122
# Train Epoch: 1 [6400/60000 (11%)]	Train Loss: 0.745996
# Train Epoch: 1 [12800/60000 (21%)]	Train Loss: 0.591825
# Train Epoch: 1 [19200/60000 (32%)]	Train Loss: 0.349725
# Train Epoch: 1 [25600/60000 (43%)]	Train Loss: 0.580695
# Train Epoch: 1 [32000/60000 (53%)]	Train Loss: 0.721900
# Train Epoch: 1 [38400/60000 (64%)]	Train Loss: 0.570072
# Train Epoch: 1 [44800/60000 (75%)]	Train Loss: 0.297463
# Train Epoch: 1 [51200/60000 (85%)]	Train Loss: 0.244455
# Train Epoch: 1 [57600/60000 (96%)]	Train Loss: 0.981835
#
# [EPOCH: 1], 	Test Loss: 0.2195, 	Test Accuracy: 93.48 %
#
# Train Epoch: 2 [0/60000 (0%)]	Train Loss: 0.486577
# Train Epoch: 2 [6400/60000 (11%)]	Train Loss: 0.473376
# Train Epoch: 2 [12800/60000 (21%)]	Train Loss: 0.135657
# Train Epoch: 2 [19200/60000 (32%)]	Train Loss: 0.298237
# Train Epoch: 2 [25600/60000 (43%)]	Train Loss: 0.412272
# Train Epoch: 2 [32000/60000 (53%)]	Train Loss: 0.376150
# Train Epoch: 2 [38400/60000 (64%)]	Train Loss: 0.370757
# Train Epoch: 2 [44800/60000 (75%)]	Train Loss: 0.469892
# Train Epoch: 2 [51200/60000 (85%)]	Train Loss: 0.396936
# Train Epoch: 2 [57600/60000 (96%)]	Train Loss: 0.473313
#
# [EPOCH: 2], 	Test Loss: 0.1730, 	Test Accuracy: 94.73 %
#
# Train Epoch: 3 [0/60000 (0%)]	Train Loss: 0.184196
# Train Epoch: 3 [6400/60000 (11%)]	Train Loss: 0.507486
# Train Epoch: 3 [12800/60000 (21%)]	Train Loss: 0.377188
# Train Epoch: 3 [19200/60000 (32%)]	Train Loss: 0.325602
# Train Epoch: 3 [25600/60000 (43%)]	Train Loss: 0.096517
# Train Epoch: 3 [32000/60000 (53%)]	Train Loss: 0.155983
# Train Epoch: 3 [38400/60000 (64%)]	Train Loss: 0.135666
# Train Epoch: 3 [44800/60000 (75%)]	Train Loss: 0.179562
# Train Epoch: 3 [51200/60000 (85%)]	Train Loss: 0.364445
# Train Epoch: 3 [57600/60000 (96%)]	Train Loss: 0.151131
#
# [EPOCH: 3], 	Test Loss: 0.1480, 	Test Accuracy: 95.40 %
#
# Train Epoch: 4 [0/60000 (0%)]	Train Loss: 0.166550
# Train Epoch: 4 [6400/60000 (11%)]	Train Loss: 0.185014
# Train Epoch: 4 [12800/60000 (21%)]	Train Loss: 0.134637
# Train Epoch: 4 [19200/60000 (32%)]	Train Loss: 0.122604
# Train Epoch: 4 [25600/60000 (43%)]	Train Loss: 0.163792
# Train Epoch: 4 [32000/60000 (53%)]	Train Loss: 0.236290
# Train Epoch: 4 [38400/60000 (64%)]	Train Loss: 0.372978
# Train Epoch: 4 [44800/60000 (75%)]	Train Loss: 0.180945
# Train Epoch: 4 [51200/60000 (85%)]	Train Loss: 0.201479
# Train Epoch: 4 [57600/60000 (96%)]	Train Loss: 0.217774
#
# [EPOCH: 4], 	Test Loss: 0.1285, 	Test Accuracy: 96.00 %
#
# Train Epoch: 5 [0/60000 (0%)]	Train Loss: 0.084667
# Train Epoch: 5 [6400/60000 (11%)]	Train Loss: 0.304823
# Train Epoch: 5 [12800/60000 (21%)]	Train Loss: 0.103804
# Train Epoch: 5 [19200/60000 (32%)]	Train Loss: 0.106489
# Train Epoch: 5 [25600/60000 (43%)]	Train Loss: 0.193756
# Train Epoch: 5 [32000/60000 (53%)]	Train Loss: 0.345337
# Train Epoch: 5 [38400/60000 (64%)]	Train Loss: 0.231611
# Train Epoch: 5 [44800/60000 (75%)]	Train Loss: 0.378968
# Train Epoch: 5 [51200/60000 (85%)]	Train Loss: 0.297402
# Train Epoch: 5 [57600/60000 (96%)]	Train Loss: 0.331880
#
# [EPOCH: 5], 	Test Loss: 0.1204, 	Test Accuracy: 96.25 %
#
# Train Epoch: 6 [0/60000 (0%)]	Train Loss: 0.067847
# Train Epoch: 6 [6400/60000 (11%)]	Train Loss: 0.391748
# Train Epoch: 6 [12800/60000 (21%)]	Train Loss: 0.117414
# Train Epoch: 6 [19200/60000 (32%)]	Train Loss: 0.192286
# Train Epoch: 6 [25600/60000 (43%)]	Train Loss: 0.166025
# Train Epoch: 6 [32000/60000 (53%)]	Train Loss: 0.505387
# Train Epoch: 6 [38400/60000 (64%)]	Train Loss: 0.217449
# Train Epoch: 6 [44800/60000 (75%)]	Train Loss: 0.207050
# Train Epoch: 6 [51200/60000 (85%)]	Train Loss: 0.178074
# Train Epoch: 6 [57600/60000 (96%)]	Train Loss: 0.089791
#
# [EPOCH: 6], 	Test Loss: 0.1071, 	Test Accuracy: 96.74 %
#
# Train Epoch: 7 [0/60000 (0%)]	Train Loss: 0.346426
# Train Epoch: 7 [6400/60000 (11%)]	Train Loss: 0.214718
# Train Epoch: 7 [12800/60000 (21%)]	Train Loss: 0.250193
# Train Epoch: 7 [19200/60000 (32%)]	Train Loss: 0.225185
# Train Epoch: 7 [25600/60000 (43%)]	Train Loss: 0.476766
# Train Epoch: 7 [32000/60000 (53%)]	Train Loss: 0.243998
# Train Epoch: 7 [38400/60000 (64%)]	Train Loss: 0.076505
# Train Epoch: 7 [44800/60000 (75%)]	Train Loss: 0.141320
# Train Epoch: 7 [51200/60000 (85%)]	Train Loss: 0.306182
# Train Epoch: 7 [57600/60000 (96%)]	Train Loss: 0.099495
#
# [EPOCH: 7], 	Test Loss: 0.1055, 	Test Accuracy: 96.74 %
#
# Train Epoch: 8 [0/60000 (0%)]	Train Loss: 0.267579
# Train Epoch: 8 [6400/60000 (11%)]	Train Loss: 0.204905
# Train Epoch: 8 [12800/60000 (21%)]	Train Loss: 0.406061
# Train Epoch: 8 [19200/60000 (32%)]	Train Loss: 0.191464
# Train Epoch: 8 [25600/60000 (43%)]	Train Loss: 0.184235
# Train Epoch: 8 [32000/60000 (53%)]	Train Loss: 0.037216
# Train Epoch: 8 [38400/60000 (64%)]	Train Loss: 0.461187
# Train Epoch: 8 [44800/60000 (75%)]	Train Loss: 0.195450
# Train Epoch: 8 [51200/60000 (85%)]	Train Loss: 0.121539
# Train Epoch: 8 [57600/60000 (96%)]	Train Loss: 0.038898
#
# [EPOCH: 8], 	Test Loss: 0.0977, 	Test Accuracy: 96.92 %
#
# Train Epoch: 9 [0/60000 (0%)]	Train Loss: 0.284318
# Train Epoch: 9 [6400/60000 (11%)]	Train Loss: 0.276694
# Train Epoch: 9 [12800/60000 (21%)]	Train Loss: 0.269957
# Train Epoch: 9 [19200/60000 (32%)]	Train Loss: 0.205002
# Train Epoch: 9 [25600/60000 (43%)]	Train Loss: 0.111247
# Train Epoch: 9 [32000/60000 (53%)]	Train Loss: 0.232081
# Train Epoch: 9 [38400/60000 (64%)]	Train Loss: 0.207599
# Train Epoch: 9 [44800/60000 (75%)]	Train Loss: 0.240822
# Train Epoch: 9 [51200/60000 (85%)]	Train Loss: 0.173217
# Train Epoch: 9 [57600/60000 (96%)]	Train Loss: 0.113064
#
# [EPOCH: 9], 	Test Loss: 0.0937, 	Test Accuracy: 97.08 %
#
# Train Epoch: 10 [0/60000 (0%)]	Train Loss: 0.452351
# Train Epoch: 10 [6400/60000 (11%)]	Train Loss: 0.221641
# Train Epoch: 10 [12800/60000 (21%)]	Train Loss: 0.148306
# Train Epoch: 10 [19200/60000 (32%)]	Train Loss: 0.103316
# Train Epoch: 10 [25600/60000 (43%)]	Train Loss: 0.103911
# Train Epoch: 10 [32000/60000 (53%)]	Train Loss: 0.148825
# Train Epoch: 10 [38400/60000 (64%)]	Train Loss: 0.145274
# Train Epoch: 10 [44800/60000 (75%)]	Train Loss: 0.183323
# Train Epoch: 10 [51200/60000 (85%)]	Train Loss: 0.233515
# Train Epoch: 10 [57600/60000 (96%)]	Train Loss: 0.088627
#
# [EPOCH: 10], 	Test Loss: 0.0897, 	Test Accuracy: 97.27 %
#
# Train Epoch: 11 [0/60000 (0%)]	Train Loss: 0.051034
# Train Epoch: 11 [6400/60000 (11%)]	Train Loss: 0.249533
# Train Epoch: 11 [12800/60000 (21%)]	Train Loss: 0.403748
# Train Epoch: 11 [19200/60000 (32%)]	Train Loss: 0.094603
# Train Epoch: 11 [25600/60000 (43%)]	Train Loss: 0.123165
# Train Epoch: 11 [32000/60000 (53%)]	Train Loss: 0.181533
# Train Epoch: 11 [38400/60000 (64%)]	Train Loss: 0.406179
# Train Epoch: 11 [44800/60000 (75%)]	Train Loss: 0.194796
# Train Epoch: 11 [51200/60000 (85%)]	Train Loss: 0.149278
# Train Epoch: 11 [57600/60000 (96%)]	Train Loss: 0.148642
#
# [EPOCH: 11], 	Test Loss: 0.0856, 	Test Accuracy: 97.34 %
#
# Train Epoch: 12 [0/60000 (0%)]	Train Loss: 0.213091
# Train Epoch: 12 [6400/60000 (11%)]	Train Loss: 0.128735
# Train Epoch: 12 [12800/60000 (21%)]	Train Loss: 0.254822
# Train Epoch: 12 [19200/60000 (32%)]	Train Loss: 0.155838
# Train Epoch: 12 [25600/60000 (43%)]	Train Loss: 0.057260
# Train Epoch: 12 [32000/60000 (53%)]	Train Loss: 0.333947
# Train Epoch: 12 [38400/60000 (64%)]	Train Loss: 0.189696
# Train Epoch: 12 [44800/60000 (75%)]	Train Loss: 0.245867
# Train Epoch: 12 [51200/60000 (85%)]	Train Loss: 0.426582
# Train Epoch: 12 [57600/60000 (96%)]	Train Loss: 0.082658
#
# [EPOCH: 12], 	Test Loss: 0.0815, 	Test Accuracy: 97.42 %
#
# Train Epoch: 13 [0/60000 (0%)]	Train Loss: 0.263387
# Train Epoch: 13 [6400/60000 (11%)]	Train Loss: 0.162744
# Train Epoch: 13 [12800/60000 (21%)]	Train Loss: 0.257375
# Train Epoch: 13 [19200/60000 (32%)]	Train Loss: 0.424208
# Train Epoch: 13 [25600/60000 (43%)]	Train Loss: 0.335592
# Train Epoch: 13 [32000/60000 (53%)]	Train Loss: 0.113028
# Train Epoch: 13 [38400/60000 (64%)]	Train Loss: 0.039467
# Train Epoch: 13 [44800/60000 (75%)]	Train Loss: 0.264727
# Train Epoch: 13 [51200/60000 (85%)]	Train Loss: 0.239786
# Train Epoch: 13 [57600/60000 (96%)]	Train Loss: 0.039859
#
# [EPOCH: 13], 	Test Loss: 0.0808, 	Test Accuracy: 97.44 %
#
# Train Epoch: 14 [0/60000 (0%)]	Train Loss: 0.221162
# Train Epoch: 14 [6400/60000 (11%)]	Train Loss: 0.060790
# Train Epoch: 14 [12800/60000 (21%)]	Train Loss: 0.084774
# Train Epoch: 14 [19200/60000 (32%)]	Train Loss: 0.165252
# Train Epoch: 14 [25600/60000 (43%)]	Train Loss: 0.377603
# Train Epoch: 14 [32000/60000 (53%)]	Train Loss: 0.039968
# Train Epoch: 14 [38400/60000 (64%)]	Train Loss: 0.118467
# Train Epoch: 14 [44800/60000 (75%)]	Train Loss: 0.149073
# Train Epoch: 14 [51200/60000 (85%)]	Train Loss: 0.065771
# Train Epoch: 14 [57600/60000 (96%)]	Train Loss: 0.092633
#
# [EPOCH: 14], 	Test Loss: 0.0803, 	Test Accuracy: 97.44 %
#
# Train Epoch: 15 [0/60000 (0%)]	Train Loss: 0.139818
# Train Epoch: 15 [6400/60000 (11%)]	Train Loss: 0.035521
# Train Epoch: 15 [12800/60000 (21%)]	Train Loss: 0.060591
# Train Epoch: 15 [19200/60000 (32%)]	Train Loss: 0.163921
# Train Epoch: 15 [25600/60000 (43%)]	Train Loss: 0.126998
# Train Epoch: 15 [32000/60000 (53%)]	Train Loss: 0.375754
# Train Epoch: 15 [38400/60000 (64%)]	Train Loss: 0.117347
# Train Epoch: 15 [44800/60000 (75%)]	Train Loss: 0.108339
# Train Epoch: 15 [51200/60000 (85%)]	Train Loss: 0.048882
# Train Epoch: 15 [57600/60000 (96%)]	Train Loss: 0.032607
#
# [EPOCH: 15], 	Test Loss: 0.0772, 	Test Accuracy: 97.60 %
#
# Train Epoch: 16 [0/60000 (0%)]	Train Loss: 0.075005
# Train Epoch: 16 [6400/60000 (11%)]	Train Loss: 0.066197
# Train Epoch: 16 [12800/60000 (21%)]	Train Loss: 0.043456
# Train Epoch: 16 [19200/60000 (32%)]	Train Loss: 0.025799
# Train Epoch: 16 [25600/60000 (43%)]	Train Loss: 0.085094
# Train Epoch: 16 [32000/60000 (53%)]	Train Loss: 0.133733
# Train Epoch: 16 [38400/60000 (64%)]	Train Loss: 0.335036
# Train Epoch: 16 [44800/60000 (75%)]	Train Loss: 0.131386
# Train Epoch: 16 [51200/60000 (85%)]	Train Loss: 0.028056
# Train Epoch: 16 [57600/60000 (96%)]	Train Loss: 0.130872
#
# [EPOCH: 16], 	Test Loss: 0.0746, 	Test Accuracy: 97.76 %
#
# Train Epoch: 17 [0/60000 (0%)]	Train Loss: 0.336971
# Train Epoch: 17 [6400/60000 (11%)]	Train Loss: 0.154266
# Train Epoch: 17 [12800/60000 (21%)]	Train Loss: 0.191008
# Train Epoch: 17 [19200/60000 (32%)]	Train Loss: 0.022580
# Train Epoch: 17 [25600/60000 (43%)]	Train Loss: 0.121484
# Train Epoch: 17 [32000/60000 (53%)]	Train Loss: 0.071195
# Train Epoch: 17 [38400/60000 (64%)]	Train Loss: 0.061473
# Train Epoch: 17 [44800/60000 (75%)]	Train Loss: 0.121491
# Train Epoch: 17 [51200/60000 (85%)]	Train Loss: 0.061093
# Train Epoch: 17 [57600/60000 (96%)]	Train Loss: 0.517169
#
# [EPOCH: 17], 	Test Loss: 0.0703, 	Test Accuracy: 97.85 %
#
# Train Epoch: 18 [0/60000 (0%)]	Train Loss: 0.075184
# Train Epoch: 18 [6400/60000 (11%)]	Train Loss: 0.117348
# Train Epoch: 18 [12800/60000 (21%)]	Train Loss: 0.029478
# Train Epoch: 18 [19200/60000 (32%)]	Train Loss: 0.174654
# Train Epoch: 18 [25600/60000 (43%)]	Train Loss: 0.213804
# Train Epoch: 18 [32000/60000 (53%)]	Train Loss: 0.270869
# Train Epoch: 18 [38400/60000 (64%)]	Train Loss: 0.035893
# Train Epoch: 18 [44800/60000 (75%)]	Train Loss: 0.113140
# Train Epoch: 18 [51200/60000 (85%)]	Train Loss: 0.271905
# Train Epoch: 18 [57600/60000 (96%)]	Train Loss: 0.183659
#
# [EPOCH: 18], 	Test Loss: 0.0700, 	Test Accuracy: 97.95 %
#
# Train Epoch: 19 [0/60000 (0%)]	Train Loss: 0.219984
# Train Epoch: 19 [6400/60000 (11%)]	Train Loss: 0.123730
# Train Epoch: 19 [12800/60000 (21%)]	Train Loss: 0.132359
# Train Epoch: 19 [19200/60000 (32%)]	Train Loss: 0.069133
# Train Epoch: 19 [25600/60000 (43%)]	Train Loss: 0.055114
# Train Epoch: 19 [32000/60000 (53%)]	Train Loss: 0.047068
# Train Epoch: 19 [38400/60000 (64%)]	Train Loss: 0.152973
# Train Epoch: 19 [44800/60000 (75%)]	Train Loss: 0.075754
# Train Epoch: 19 [51200/60000 (85%)]	Train Loss: 0.369542
# Train Epoch: 19 [57600/60000 (96%)]	Train Loss: 0.038724
#
# [EPOCH: 19], 	Test Loss: 0.0693, 	Test Accuracy: 97.88 %
#
# Train Epoch: 20 [0/60000 (0%)]	Train Loss: 0.140297
# Train Epoch: 20 [6400/60000 (11%)]	Train Loss: 0.085179
# Train Epoch: 20 [12800/60000 (21%)]	Train Loss: 0.106837
# Train Epoch: 20 [19200/60000 (32%)]	Train Loss: 0.098273
# Train Epoch: 20 [25600/60000 (43%)]	Train Loss: 0.612135
# Train Epoch: 20 [32000/60000 (53%)]	Train Loss: 0.079614
# Train Epoch: 20 [38400/60000 (64%)]	Train Loss: 0.087931
# Train Epoch: 20 [44800/60000 (75%)]	Train Loss: 0.007477
# Train Epoch: 20 [51200/60000 (85%)]	Train Loss: 0.278890
# Train Epoch: 20 [57600/60000 (96%)]	Train Loss: 0.178940
#
# [EPOCH: 20], 	Test Loss: 0.0689, 	Test Accuracy: 97.91 %
